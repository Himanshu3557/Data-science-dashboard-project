# %% [markdown]
# <a href="https://colab.research.google.com/github/Himanshu3557/Data-science-dashboard-project/blob/main/Activity4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
df = pd.read_excel('/content/drive/MyDrive/Final_Cleaned_No_Zero (1).xlsx')

# %%
# !pip install plotly pandas -q

# %%
import pandas as pd
import plotly.express as px
import plotly.graph_objects as go

# %%
import pandas as pd

print(df.shape)
df.head()
# Out:
# (604, 12)
#    Order_ID Order_Date Customer        City Product     Category  Qty  Price  \
# 0  ORD10002 2026-01-03    Rahul      Jaipur   Shoes      Fashion    8  13441
# 1  ORD10005 2025-09-19     Riya  Chandigarh   Table    Furniture    3    622
# 2  ORD10006 2025-05-29    Priya     Unknown  Laptop  Electronics    5  11445
# 3  ORD10008 2025-03-05    Pooja  Chandigarh   Phone  Electronics    1  40157
# 4  ORD10009 2025-03-05    Priya     Unknown   Shoes      Fashion    7  43244
#
#    Discount     Payment     Status  Sales_Amount
# 0         5         Upi  Cancelled     102151.60
# 1         5        Cash  Cancelled       1772.70
# 2        20  Netbanking    Pending      45780.00
# 3        15         Upi  Cancelled      34133.45
# 4        10  Netbanking  Delivered     272437.20

# %%
print(df.columns.tolist())
# Out:
# ['Order_ID', 'Order_Date', 'Customer', 'City', 'Product', 'Category', 'Qty', 'Price', 'Discount', 'Payment', 'Status', 'Sales_Amount']

# %%
['Category',
 'Product',
 'City',
 'Sales_Amount',
 'Quantity',
 'Payment']
# Out:
# ['Category', 'Product', 'City', 'Sales_Amount', 'Quantity', 'Payment']

# %%
fig = px.sunburst(
    df,
    path=['Category', 'Product', 'City'],
    values='Sales_Amount',
    title='Sales Distribution by Category, Product and City'
)

fig.update_layout(
    title_x=0.5,
    width=900,
    height=700
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
sankey_df = df.groupby(
    ['Category','Product']
)['Sales_Amount'].sum().reset_index()

sankey_df.head()
# Out:
#       Category Product  Sales_Amount
# 0  Electronics  Laptop   11812834.90
# 1  Electronics   Phone   11470211.40
# 2      Fashion   Shoes   11371073.75
# 3      Fashion   Watch   12023610.40
# 4    Furniture   Chair   11958081.75

# %%
labels = list(
    pd.concat([
        sankey_df['Category'],
        sankey_df['Product']
    ]).unique()
)

label_dict = {k:v for v,k in enumerate(labels)}

print(labels)
# Out:
# ['Electronics', 'Fashion', 'Furniture', 'Laptop', 'Phone', 'Shoes', 'Watch', 'Chair', 'Table']

# %%
source = sankey_df['Category'].map(label_dict)
target = sankey_df['Product'].map(label_dict)
value = sankey_df['Sales_Amount']

# %%
fig = go.Figure(
    data=[
        go.Sankey(
            node=dict(
                pad=15,
                thickness=20,
                label=labels
            ),
            link=dict(
                source=source,
                target=target,
                value=value
            )
        )
    ]
)

fig.update_layout(
    title_text="Category → Product Sales Flow",
    title_x=0.5,
    width=1000,
    height=600
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.sunburst(
    df,
    path=['Category','Product','City'],
    values='Sales_Amount'
)

fig.update_traces(
    hovertemplate=
    "<b>%{label}</b><br>" +
    "Sales: %{value}<br>" +
    "Percent: %{percentParent:.2%}<extra></extra>"
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig.update_layout(
    template="plotly_dark"
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
new_row = pd.DataFrame({
    'Category':['Electronics'],
    'Product':['Laptop'],
    'City':['Delhi'],
    'Sales_Amount':[50000]
})

df = pd.concat([df,new_row], ignore_index=True)

# %%
import pandas as pd
import plotly.express as px
import plotly.graph_objects as go


# SUNBURST
sunburst = px.sunburst(
    df,
    path=['Category','Product','City'],
    values='Sales_Amount',
    title='Sales Hierarchy Dashboard'
)

sunburst.update_layout(
    title_x=0.5,
    template='plotly_dark'
)

sunburst.show()

# SANKEY
sankey_df = df.groupby(
    ['Category','Product']
)['Sales_Amount'].sum().reset_index()

labels = list(
    pd.concat([
        sankey_df['Category'],
        sankey_df['Product']
    ]).unique()
)

label_dict = {k:v for v,k in enumerate(labels)}

source = sankey_df['Category'].map(label_dict)
target = sankey_df['Product'].map(label_dict)
value = sankey_df['Sales_Amount']

sankey = go.Figure(
    data=[
        go.Sankey(
            node=dict(
                pad=15,
                thickness=20,
                label=labels
            ),
            link=dict(
                source=source,
                target=target,
                value=value
            )
        )
    ]
)

sankey.update_layout(
    title='Category → Product Sales Flow',
    title_x=0.5,
    template='plotly_dark'
)

sankey.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
